# %% [markdown]
# <a href="https://colab.research.google.com/github/amitthakur2013/Project_Clg_Tumor_Detection/blob/main/Copy_of_Brain_Tumor_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Necessary modules**

# %%
import tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import skimage.io
import tqdm
import os

from tqdm import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray 

from sklearn.utils import shuffle 
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import InputLayer, ZeroPadding2D, Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

print("All Imports Successfull!")

# %matplotlib inline
# Out:
# All Imports Successfull!

# %% [markdown]
# **Importing/ Vewing/ Pre-Processing Dataset**

# %%
# Importing Dataset

cancerous = os.listdir('/content/brain_tumor_dataset/yes')
non_cancerous = os.listdir('/content/brain_tumor_dataset/no')

# %%
len(cancerous), len(non_cancerous)
# Out:
# (155, 98)

# %%
# Viewing Dataset - Cancerous

fig, ax=plt.subplots(nrows = 1, ncols =5, figsize = (20,20)) 

for i in tqdm(range(0,5)):
  rand = np.random.randint(len(cancerous))
  img = imread('/content/brain_tumor_dataset/yes/'+cancerous[rand])
  img = resize(img, (224,224))
  ax[i].imshow(img)
  ax[i].axis('off')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 24.70it/s]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize = (20,20))

for i in tqdm(range(0, 5)):
    rand = np.random.randint(len(non_cancerous))
    img  = imread('/content/brain_tumor_dataset/no/' + non_cancerous[rand])
    img  = resize(img, (224,224))
    ax[i].imshow(img)
    ax[i].axis('off')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 14.00it/s]

# %%
# Converting images into proper shape and storing them as  an array 

Image=[]
Label=[]

for i in tqdm(range(0, len(cancerous))):
  img=imread('/content/brain_tumor_dataset/yes/'+cancerous[i]) 
  img=resize(img, (224, 224, 3))
  Image.append(img)
  Label.append(1)

for i in tqdm(range(0,len(non_cancerous))):
  img=imread('/content/brain_tumor_dataset/no/'+non_cancerous[i])
  img=resize(img,(224, 224, 3))
  Image.append(img)
  Label.append(0)

Image=np.array(Image)
Label=np.array(Label)
# Out:
# 100%|██████████| 155/155 [00:06<00:00, 22.47it/s]
# 100%|██████████| 98/98 [00:03<00:00, 29.58it/s]

# %%
# Normalizing 

Image.min(), Image.max()
# Out:
# (0.0, 1.0)

# %%
# Shuffle the data as results are appended.

Image, Label = shuffle(Image, Label, random_state = 42)

# %%
# Viewing Image - After Shuffle

fig,ax = plt.subplots(nrows = 1, ncols = 5, figsize = (20, 20))

for i in tqdm(range(0,5)):
  rand=np.random.randint(len(Image))
  ax[i].imshow(Image[rand])
  ax[i].axis('off')
  a=Label[rand]
  if a==1:
    ax[i].set_title('Cancerous')
  else:
    ax[i].set_title('Non_Cancerous')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 308.39it/s]

# %%
# Assigning Images and Label to new variable 

X = Image
y = Label

# %%
# Splitting Data - Training and Validation

X_train, X_val, y_train, y_val=train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# Checking Shape

X_train.shape, X_val.shape
# Out:
# ((177, 224, 224, 3), (76, 224, 224, 3))

# %%
# Creating augmentation object

train_datagen  = ImageDataGenerator(rescale = 1./255,
                                    width_shift_range = 0.05,
                                    height_shift_range = 0.05,
                                    horizontal_flip = True,
                                    vertical_flip = True,
                                    rotation_range = 30,
                                    fill_mode = 'nearest',
                                    zoom_range = 0.2,
                                    shear_range = 0.2)

# Fitting to train data

train_datagen.fit(X_train)

# %% [markdown]
# **Model Building**

# %%
# Model Initialization

model = Sequential()

# %%
# Building Layers
# Input Layer 
model.add(InputLayer(input_shape = (224,224,3)))


# Adding Zero Padding
model.add(ZeroPadding2D((2,2), data_format = 'channels_last'))


# Adding Layers
model.add(Conv2D(filters = 32,  kernel_size  = (3, 3), strides=(2, 2), padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2, 2), padding = 'valid'))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 64,  kernel_size  = (3, 3), strides=(2, 2), padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2, 2), padding = 'valid'))
model.add(Dropout(0.25))


# Adding Flatten
model.add(Flatten())


# Adding Dense-FCC
model.add(Dense(units = 128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


# Adding Output 
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compiling Model

model.compile(optimizer = tensorflow.keras.optimizers.Adam(1e-5), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Defining Callbacks
filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_accuracy', 
                              mode = 'max' , 
                              patience = 15)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_accuracy', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)

callback_list = [earlystopping, checkpoint]

# %%
# Model Run

model.fit(train_datagen.flow(X_train, y_train, batch_size = 32),
          validation_data = (X_val, y_val),
          epochs = 500,
          verbose = 1,
          callbacks = callback_list)
# Out:
# Epoch 1/500
# 6/6 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.5763
# Epoch 00001: val_accuracy improved from -inf to 0.61842, saving model to ./best_weights.hdf5
# 6/6 [==============================] - 4s 722ms/step - loss: 0.8824 - accuracy: 0.5763 - val_loss: 0.6876 - val_accuracy: 0.6184
# Epoch 2/500
# 6/6 [==============================] - ETA: 0s - loss: 0.8471 - accuracy: 0.5254
# Epoch 00002: val_accuracy did not improve from 0.61842
# 6/6 [==============================] - 4s 658ms/step - loss: 0.8471 - accuracy: 0.5254 - val_loss: 0.6832 - val_accuracy: 0.6053
# Epoch 3/500
# 6/6 [==============================] - ETA: 0s - loss: 0.9454 - accuracy: 0.5254
# Epoch 00003: val_accuracy did not improve from 0.61842
# 6/6 [==============================] - 4s 747ms/step - loss: 0.9454 - accuracy: 0.5254 - val_loss: 0.6783 - val_accuracy: 0.6184
# Epoch 4/500
# 6/6 [==============================] - ETA: 0s - loss: 0.8526 - accuracy: 0.5706
# Epoch 00004: val_accuracy did not improve from 0.61842
# 6/6 [==============================] - 4s 647ms/step - loss: 0.8526 - accuracy: 0.5706 - val_loss: 0.6757 - val_accuracy: 0.6184
# Epoch 5/500
# 6/6 [==============================] - ETA: 0s - loss: 0.8232 - accuracy: 0.6328
# Epoch 00005: val_accuracy did not improve from 0.61842
# Epoch 00015: val_accuracy did not improve from 0.67105
# 6/6 [==============================] - 4s 641ms/step - loss: 0.6253 - accuracy: 0.6610 - val_loss: 0.6646 - val_accuracy: 0.6711
# Epoch 16/500
# 6/6 [==============================] - ETA: 0s - loss: 0.8389 - accuracy: 0.6215
# Epoch 00016: val_accuracy did not improve from 0.67105
# 6/6 [==============================] - 4s 667ms/step - loss: 0.8389 - accuracy: 0.6215 - val_loss: 0.6656 - val_accuracy: 0.6711
# Epoch 17/500
# 6/6 [==============================] - ETA: 0s - loss: 0.7635 - accuracy: 0.6723
# Epoch 00017: val_accuracy improved from 0.67105 to 0.68421, saving model to ./best_weights.hdf5
# 6/6 [==============================] - 4s 656ms/step - loss: 0.7635 - accuracy: 0.6723 - val_loss: 0.6657 - val_accuracy: 0.6842
# Epoch 18/500
# 6/6 [==============================] - ETA: 0s - loss: 0.7204 - accuracy: 0.6780
# Epoch 00018: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 690ms/step - loss: 0.7204 - accuracy: 0.6780 - val_loss: 0.6643 - val_accuracy: 0.6842
# Epoch 19/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6709 - accuracy: 0.6610
# Epoch 00019: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 664ms/step - loss: 0.6709 - accuracy: 0.6610 - val_loss: 0.6632 - val_accuracy: 0.6711
# Epoch 20/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6114 - accuracy: 0.7232
# Epoch 00020: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 5s 758ms/step - loss: 0.6114 - accuracy: 0.7232 - val_loss: 0.6609 - val_accuracy: 0.6579
# Epoch 21/500
# 6/6 [==============================] - ETA: 0s - loss: 0.5845 - accuracy: 0.6893
# Epoch 00021: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 647ms/step - loss: 0.5845 - accuracy: 0.6893 - val_loss: 0.6589 - val_accuracy: 0.6447
# Epoch 22/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6842 - accuracy: 0.6384
# Epoch 00022: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 657ms/step - loss: 0.6842 - accuracy: 0.6384 - val_loss: 0.6554 - val_accuracy: 0.6447
# Epoch 23/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.6667
# Epoch 00023: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 668ms/step - loss: 0.6926 - accuracy: 0.6667 - val_loss: 0.6523 - val_accuracy: 0.6447
# Epoch 24/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6635 - accuracy: 0.6836
# Epoch 00024: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 671ms/step - loss: 0.6635 - accuracy: 0.6836 - val_loss: 0.6518 - val_accuracy: 0.6316
# Epoch 25/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.6780
# Epoch 00025: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 664ms/step - loss: 0.6796 - accuracy: 0.6780 - val_loss: 0.6565 - val_accuracy: 0.6053
# Epoch 26/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.7006
# Epoch 00026: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 746ms/step - loss: 0.6312 - accuracy: 0.7006 - val_loss: 0.6532 - val_accuracy: 0.6053
# Epoch 27/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6013 - accuracy: 0.7345
# Epoch 00027: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 645ms/step - loss: 0.6013 - accuracy: 0.7345 - val_loss: 0.6530 - val_accuracy: 0.6053
# Epoch 28/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.7062
# Epoch 00028: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 653ms/step - loss: 0.6020 - accuracy: 0.7062 - val_loss: 0.6630 - val_accuracy: 0.6053
# Epoch 29/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.6667
# Epoch 00029: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 659ms/step - loss: 0.6181 - accuracy: 0.6667 - val_loss: 0.6667 - val_accuracy: 0.5921
# Epoch 30/500
# 6/6 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.6893
# Epoch 00030: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 654ms/step - loss: 0.6903 - accuracy: 0.6893 - val_loss: 0.6698 - val_accuracy: 0.5921
# Epoch 31/500
# 6/6 [==============================] - ETA: 0s - loss: 0.7142 - accuracy: 0.6497
# Epoch 00031: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 5s 754ms/step - loss: 0.7142 - accuracy: 0.6497 - val_loss: 0.6895 - val_accuracy: 0.6053
# Epoch 32/500
# 6/6 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.6328
# Epoch 00032: val_accuracy did not improve from 0.68421
# 6/6 [==============================] - 4s 665ms/step - loss: 0.7070 - accuracy: 0.6328 - val_loss: 0.6953 - val_accuracy: 0.6053

# %%
# Model Prediction
image = imread('/content/brain_tumor_dataset/Y4.jpg')
#image = imread('https://thumbor.kenhub.com/zoz_XVCq44UFroH2ds6eoOUvdtA=/fit-in/800x1600/filters:watermark(/images/logo_url.png,-10,-10,0):background_color(FFFFFF):format(jpeg)/images/library/13517/ff.jpg')
image = resize(image, (224,224,3))
imshow(image)
image = np.expand_dims(image, 0)

prediction  = model.predict_classes(image)

if prediction[0][0] == 1:
    print("Cancerous Cell")
else:
    print("Non-Cancerous Cell")
# Out:
# Cancerous Cell
